# %% [markdown]
# <a href="https://colab.research.google.com/github/vyasamayuri/11239A102_cdlab/blob/main/exp3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def is_keyword(word, keywords):
    return word.upper() in keywords
keywords1 = {"ORDER", "CANCEL", "TRACK"}
print(is_keyword("TRACK", keywords1)) # True
keywords2 = {"ISSUE", "RETURN", "SEARCH"}
print(is_keyword("RETURN", keywords2)) # True
# Out:
# True
# True
