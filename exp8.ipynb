# %% [markdown]
# <a href="https://colab.research.google.com/github/vyasamayuri/11239A102_cdlab/blob/main/exp8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def shift_reduce(expr):
    stack = []
    tokens = expr.split()
    while tokens:
        stack.append(tokens.pop(0))
        print("Shift:", stack)
        # This while loop should be part of the outer while loop's body, or a new reduction logic.
        # Assuming it's meant to be a separate reduction step after the initial shifting loop
        # and should be at the same level as the return statement for now, or within the first while.
        # For now, let's assume it should run after the shifting is done for the current token
        # and address the immediate indentation. The logical flow of the original was a bit ambiguous.

        # Re-evaluating the original intent: the inner while loop was likely meant to run repeatedly
        # for reductions *after* each shift, or after all shifts are done. Given the structure,
        # I'll place it to run after all tokens are shifted, as a separate reduction phase, if that's the intent.
        # If it's meant to be an iterative shift-reduce, the logic needs more overhaul.
        # For now, let's fix the indentation as per the error.

    # The inner while loop needs to be properly indented relative to its scope.
    # If it's part of the main function block after the first while loop finishes,
    # then it should be indented at the same level as the first 'while tokens:'.
    # Or, if it's meant to run after each token is shifted, it needs to be inside the first 'while tokens:'.
    # Given the original indentation, it seemed like a separate phase after all shifts.

    # Correcting indentation based on the most likely structural intent from the original (a two-phase process)
    # The error was about 'stack = []' not being indented under 'def'.
    # The inner while loop's body also had an indentation error.

    # Fix: Indent all function body code under 'def'.
    # Fix: Indent the body of the inner 'while' loop.

    while len(stack) >= 3 and stack[-2] == '*':
        stack[-3:] = ['E']
        print("Reduce:", stack)

    return stack

print(shift_reduce("price + discount * quantity"))
# Out:
# Shift: ['price']
# Shift: ['price', '+']
# Shift: ['price', '+', 'discount']
# Shift: ['price', '+', 'discount', '*']
# Shift: ['price', '+', 'discount', '*', 'quantity']
# Reduce: ['price', '+', 'E']
# ['price', '+', 'E']
