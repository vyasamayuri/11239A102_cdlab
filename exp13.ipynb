# %% [markdown]
# <a href="https://colab.research.google.com/github/vyasamayuri/11239A102_cdlab/blob/main/exp13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import collections

# This is a template for LEADING/TRAILING computation.
def leading_trailing(grammar):
    leading = collections.defaultdict(set)
    trailing = collections.defaultdict(set)
    # Algorithm implementation goes here
    return leading, trailing
