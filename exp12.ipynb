# %% [markdown]
# <a href="https://colab.research.google.com/github/vyasamayuri/11239A102_cdlab/blob/main/exp12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def first_follow(grammar):
    # grammar: dict with nonterminal -> list of productions
    first = {}
    follow = {}
    # Algorithm implementation goes here
    return first, follow
