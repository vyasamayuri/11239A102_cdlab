# %% [markdown]
# <a href="https://colab.research.google.com/github/vyasamayuri/11239A102_cdlab/blob/main/exp20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install PLY (run once if needed)
# !pip install ply

import ply.lex as lex

# Fix for Jupyter
__file__ = "lexer.py"

tokens = ['CHAR']

def t_CHAR(t):
    r'[^\s]'   # matches any non-space character
    return t

t_ignore = ' \t\n'

def t_error(t):
    t.lexer.skip(1)

lexer = lex.lex()

lexer.input("This is a test")

for tok in lexer:
    print(tok.value, end="")
# Out:
# Collecting ply
#   Downloading ply-3.11-py2.py3-none-any.whl.metadata (844 bytes)
# Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: ply
# Successfully installed ply-3.11
# Thisisatest
